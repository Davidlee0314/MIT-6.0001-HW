# %%
WORDLIST_FILENAME = "words.txt"


def load_words():
    """
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist
# Load the list of words into the variable wordlist
# so that it can be accessed from anywhere in the program
wordlist = load_words()

# %%
# %load hangman
# Problem Set 2, hangman.py
# Name: 
# Collaborators:
# Time spent:

# Hangman Game
# -----------------------------------
# Helper code
# You don't need to understand this helper code,
# but you will have to know how to use the functions
# (so be sure to read the docstrings!)
import random
import string


def choose_word(wordlist):
    """
    wordlist (list): list of words (strings)
    
    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code

# -----------------------------------


secret_word = choose_word(wordlist)
#secret_word = "unclasping"
letters_guessed= []

print("Welcome to the game Hangman! ")
print("I am thinking of a word that is",len(secret_word),"letters long.")  



def is_word_guessed(secret_word, letters_guessed):
    
    secret_word_list = []
    
    for i in secret_word:
        if i not in secret_word_list:
            secret_word_list.append(i)
    secret_word_list2 = secret_word_list[:]
    for i in secret_word_list:
        if i in letters_guessed:
            del secret_word_list2[secret_word_list2.index(i)]
    if secret_word_list2 == []:
        return True
    else:
        return False
    '''
    secret_word: string, the word the user is guessing; assumes all letters are
      lowercase
    letters_guessed: list (of letters), which letters have been guessed so far;
      assumes that all letters are lowercase
    returns: boolean, True if all the letters of secret_word are in letters_guessed;
      False otherwise
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"



def get_guessed_word(secret_word, letters_guessed):
    secret_word_list = []
    
    for i in secret_word:
        secret_word_list.append(i)
    
    for i in range(len(secret_word_list)):
        if secret_word_list[i] not in letters_guessed:
            secret_word_list[i] = "_ "
        else:
            pass
    secret_word_guessed = "".join(secret_word_list)
    return (secret_word_guessed)
    '''
    secret_word: string, the word the user is guessing
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string, comprised of letters, underscores (_), and spaces that represents
      which letters in secret_word have been guessed so far.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"




def get_available_letters(letters_guessed):
    available_letters = []
    alphabets = string.ascii_lowercase
    for i in alphabets:
        available_letters.append(i)
    
    available_letters2 = available_letters[:]
    
    for i in available_letters:
        if i in letters_guessed:
            del available_letters2[available_letters2.index(i)]
    return "".join(available_letters2)


    '''
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string (of letters), comprised of letters that represents which letters have not
      yet been guessed.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"

    
    

def hangman(secret_word):
    guess = 6
    warning = 3
    vowels = "aeiou"
    
    while is_word_guessed(secret_word, letters_guessed) == False:
        print("You have",guess,"guesses left.")
        print(get_available_letters(letters_guessed))
        letter_guess = input("Please guess a letter:")
        
        if letter_guess.isalnum() == False or len(letter_guess) > 1:
            warning -= 1
            print("Oops! That is not a valid letter. You have",warning,"warnings left:",get_guessed_word(secret_word, letters_guessed))
        
        elif letter_guess.lower() in letters_guessed:
            warning -= 1
            print("Oops! You've already guessed that letter. You have",warning,"warnings left:",get_guessed_word(secret_word, letters_guessed))
        
        else:
            letters_guessed.append(letter_guess)
            if letter_guess.lower() not in secret_word and letter_guess.lower() in vowels:
                guess -= 2
                print("Oops! That letter is not in my word:",get_guessed_word(secret_word, letters_guessed))

            elif letter_guess.lower() not in secret_word:
                guess -= 1

                print("Oops! That letter is not in my word:",get_guessed_word(secret_word, letters_guessed))

            elif letter_guess.lower() in secret_word:
                print("Good guess:",get_guessed_word(secret_word, letters_guessed))
            
        if guess <= 0 or warning ==0 :
            return (False,guess)
        print("-----------------")
        
    secret_word_list= []
    for i in secret_word:
        if i not in secret_word_list:
            secret_word_list.append(i)
    
    return (True, guess*len(secret_word_list))
            
    

        
    '''
    secret_word: string, the secret word to guess.
    
    Starts up an interactive game of Hangman.
    
    * At the start of the game, let the user know how many 
      letters the secret_word contains and how many guesses s/he starts with.
      
    * The user should start with 6 guesses

    * Before each round, you should display to the user how many guesses
      s/he has left and the letters that the user has not yet guessed.
    
    * Ask the user to supply one guess per round. Remember to make
      sure that the user puts in a letter!
    
    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computer's word.

    * After each guess, you should display to the user the 
      partially guessed word so far.
    
    Follows the other limitations detailed in the problem write-up.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"




# When you've completed your hangman function, scroll down to the bottom
# of the file and uncomment the first two lines to test
#(hint: you might want to pick your own
# secret_word while you're doing your own testing)

t = hangman(secret_word)
if t[0] == True:
    print("Congratulations, you won!\nYour total score for this game is:",t[1])
else:
    print("Sorry, you ran out of guesses. The word was",secret_word)

# %%
# -----------------------------------

secret_word = "unclasping"
letters_guessed= []

print("Welcome to the game Hangman! ")
print("I am thinking of a word that is",len(secret_word),"letters long.") 

import string

def match_with_gaps(my_word, other_word):
    my_word_dict = {}
    other_word_dict = {}
    length = 0
    alphabet = list(string.ascii_lowercase)
    
    for i in range(len(my_word)):
        if my_word[i] == " ":
            pass
        else:
            my_word_dict[length] = my_word[i]
            length += 1
            
            if my_word[i] != "_" and my_word[i] in alphabet :
                del alphabet[alphabet.index(my_word[i])]

    if len(other_word) != length:
        return False
                
    for i in range(len(other_word)):
        other_word_dict[i] = other_word[i]
    
    my_word_dict2 = my_word_dict.copy()
    
    for key,value in my_word_dict.items():
        if my_word_dict[key] == other_word_dict[key] and key in my_word_dict2:
            del my_word_dict2[key]
        
        elif value == "_" and other_word_dict[key] not in alphabet:
            return False
        
        elif value == "_" and other_word_dict[key] in alphabet:
            del my_word_dict2[key]
        
    if my_word_dict2 == {}:
        return True
    else:
        return (False,my_word_dict2)
    '''
    my_word: string with _ characters, current guess of secret word
    other_word: string, regular English word
    returns: boolean, True if all the actual letters of my_word match the 
        corresponding letters of other_word, or the letter is the special symbol
        _ , and my_word and other_word are of the same length;
        False otherwise: 
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"




def show_possible_matches(my_word):
    low = 0
    high = 55900
    word_possible = []
    mid = int(len(wordlist)/2)
    length = 0
    a = 0
    b = 1
    
    for i in range(len(my_word)):
        if my_word[i] == " ":
            pass
        else:
            length += 1
        
    while len(wordlist[mid]) != length:

        if len(wordlist[mid]) > length:
            high = mid

        elif len(wordlist[mid]) < length:
            low = mid

        mid = int(( high + low )/ 2)
    
    while (mid - a) >= 0:
        if len(wordlist[mid - a]) == length:
            if match_with_gaps(my_word,wordlist[mid - a]) == True:
                word_possible.append(wordlist[mid - a])
            a += 1 
        else:
            break
            
    while (mid + b) < 55900:
        
        if len(wordlist[mid + b]) == length:
            if match_with_gaps(my_word,wordlist[mid + b]) == True:
                word_possible.append(wordlist[mid + b])
            b += 1 
        else:
            break
        

    return (word_possible)
    '''
    my_word: string with _ characters, current guess of secret word
    returns: nothing, but should print out every word in wordlist that matches my_word
             Keep in mind that in hangman when a letter is guessed, all the positions
             at which that letter occurs in the secret word are revealed.
             Therefore, the hidden letter(_ ) cannot be one of the letters in the word
             that has already been revealed.

    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"




def hangman_with_hints(secret_word):
    guess = 6
    warning = 3
    vowels = "aeiou"
    
    while is_word_guessed(secret_word, letters_guessed) == False:
        print("You have",guess,"guesses left.")
        print(get_available_letters(letters_guessed))
        print("Type \"*\" for hints")
        letter_guess = input("Please guess a letter:")
        
        if "*" in letter_guess:
            print("Possible word matches are: ",show_possible_matches(get_guessed_word(secret_word, letters_guessed)))
        else:
        
            if letter_guess.isalnum() == False or len(letter_guess) > 1:
                warning -= 1
                print("Oops! That is not a valid letter. You have",warning,"warnings left:",get_guessed_word(secret_word, letters_guessed))

            elif letter_guess.lower() in letters_guessed:
                warning -= 1
                print("Oops! You've already guessed that letter. You have",warning,"warnings left:",get_guessed_word(secret_word, letters_guessed))

            else:
                letters_guessed.append(letter_guess)
                if letter_guess.lower() not in secret_word and letter_guess.lower() in vowels:
                    guess -= 2
                    print("Oops! That letter is not in my word:",get_guessed_word(secret_word, letters_guessed))

                elif letter_guess.lower() not in secret_word:
                    guess -= 1

                    print("Oops! That letter is not in my word:",get_guessed_word(secret_word, letters_guessed))

                elif letter_guess.lower() in secret_word:
                    print("Good guess:",get_guessed_word(secret_word, letters_guessed))
            
        if guess <= 0 or warning ==0 :
            return (False,guess)
        print("-----------------")
        
    secret_word_list= []
    for i in secret_word:
        if i not in secret_word_list:
            secret_word_list.append(i)
    
    return (True, guess*len(secret_word_list))
    '''
    secret_word: string, the secret word to guess.
    
    Starts up an interactive game of Hangman.
    
    * At the start of the game, let the user know how many 
      letters the secret_word contains and how many guesses s/he starts with.
      
    * The user should start with 6 guesses
    
    * Before each round, you should display to the user how many guesses
      s/he has left and the letters that the user has not yet guessed.
    
    * Ask the user to supply one guess per round. Make sure to check that the user guesses a letter
      
    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computer's word.

    * After each guess, you should display to the user the 
      partially guessed word so far.
      
    * If the guess is the symbol *, print out all words in wordlist that
      matches the current guessed word. 
    
    Follows the other limitations detailed in the problem write-up.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
t = hangman_with_hints(secret_word)
if t[0] == True:
    print("Congratulations, you won!\nYour total score for this game is:",t[1])
else:
    print("Sorry, you ran out of guesses. The word was",secret_word)



# When you've completed your hangman_with_hint function, comment the two similar
# lines above that were used to run the hangman function, and then uncomment
# these two lines and run this file to test!
# Hint: You might want to pick your own secret_word while you're testing.


#if __name__ == "__main__":
    # pass

    # To test part 2, comment out the pass line above and
    # uncomment the following two lines.
    
    #secret_word = choose_word(wordlist)
    #hangman(secret_word)

###############
    
    # To test part 3 re-comment out the above lines and 
    # uncomment the following two lines. 
    
    #secret_word = choose_word(wordlist)
    #hangman_with_hints(secret_word)

# %%
a = "*"

b = "*"

a in b

# %%
#2nd version of matching words

def show_possible_matches(my_word):
    possible_word = []
    for i in wordlist:
        if match_with_gaps(my_word,i) == True:
            possible_word.append(i)
        else:
            pass
    if possible_word == []:
        print("No matches found! ")
    else:
        return (possible_word)

# %%
print(show_possible_matches("t_ _ t"))

# %%
 match_with_gaps("a_ ple", "apple")
